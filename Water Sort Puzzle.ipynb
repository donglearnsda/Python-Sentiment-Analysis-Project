# %% [markdown]
# # API data

# %% [markdown]
# ## Install libraries

# %%
# !pip install google_play_scraper
# Out:
# Requirement already satisfied: google_play_scraper in c:\users\84962\anaconda3\lib\site-packages (1.2.4)

# %%
# !pip install app_store_scraper
# Out:
# Requirement already satisfied: app_store_scraper in c:\users\84962\anaconda3\lib\site-packages (0.3.5)
# Requirement already satisfied: requests==2.23.0 in c:\users\84962\anaconda3\lib\site-packages (from app_store_scraper) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\84962\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\84962\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\84962\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\84962\anaconda3\lib\site-packages (from requests==2.23.0->app_store_scraper) (2022.9.14)

# %% [markdown]
# ## Import libraries

# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %% [markdown]
# ## API users' review from CH Play and AppStore

# %%
g_reviews = reviews_all(
        "sort.water.puzzle.pour.color.tubes.sorting.game",
        sleep_milliseconds=0, # mặc định là 0
        lang='en', # mặc định là 'vi'
        country='us', # mặc định là 'us'
        sort=Sort.NEWEST, # mặc định là Sort.MOST_REELEVANT
    )
a_reviews = AppStore('us', 'sort-water-color-puzzle', '1575680675')
a_reviews.review()
# Out:
# 2023-06-25 09:52:35,458 [INFO] Base - Initialised: AppStore('us', 'sort-water-color-puzzle', 1575680675)
# 2023-06-25 09:52:35,458 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/sort-water-color-puzzle/id1575680675
# 2023-06-25 09:52:38,305 [INFO] Base - [id:1575680675] Fetched 558 reviews (558 fetched in total)

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))
 
g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent' : 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'us'
g_df2
# Out:
#             source                             review_id            user_name  \
# 0      Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e       Ernesto Abussi
# 1      Google Play  4558d26c-c223-46f1-a147-6b9e481ca104        Mary Pinkston
# 2      Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329               Viking
# 3      Google Play  e5251950-a650-493f-aa44-bb555906f599         Elsie Ludick
# 4      Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff         Hasan Khalil
# ...            ...                                   ...                  ...
# 15158  Google Play  7323363a-1209-493a-801e-746e45569ccf         Mylene Ferry
# 15159  Google Play  7ee45343-9457-478e-b8db-4b80901cbcd5  Dametia Jo Woodruff
# 15160  Google Play  2a8decff-f1ac-4b89-a82c-cde58f04cea9          ikram ikram
# 15161  Google Play  a9131ad5-7635-4676-8803-39cbfb4d096b         Quan Hickman
# 15162  Google Play  cf6a71ec-c006-4265-b594-155055632e21          Tyler Smith
#
#       review_title                                 review_description  rating  \
# 0             None  It's the best adults if r child is under 12 it...       5
# 1             None                                            Logical       5
# 2             None  Id rate higher if it didnt force the extra bot...       2
# 3             None                                     Wonderful game       5
# 4             None                                               Nice       5
# ...            ...                                                ...     ...
# 15158         None                        🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩❤️🧡💛💚💙💜🖤📲💽🛋️📱       5
# 15159         None                                          Homemaker       5
# 15160         None                                              Super       5
# 15161         None           Please let me play with it please let me       5
# 15162         None           Nothing like the tiktok ad and boring af       1
#
#        thumbs_up         review_date developer_response  \
# 0              0 2023-06-23 13:51:00               None
# 1              0 2023-06-20 23:00:46               None
# 2              0 2023-06-19 06:58:16               None
# 3              0 2023-06-19 01:56:45               None
# 4              0 2023-06-18 07:50:42               None
# ...          ...                 ...                ...
# 15158         18 2021-06-29 15:39:17               None
# 15159         10 2021-06-29 14:23:06               None
# 15160          4 2021-06-29 04:26:55               None
# 15161         42 2021-06-27 12:53:49               None
# 15162        101 2021-06-26 22:44:06               None
#
#       developer_response_date appVersion laguage_code country_code
# 0                         NaT      1.7.5           en           us
# 1                         NaT      1.5.0           en           us
# 2                         NaT      1.7.5           en           us
# 3                         NaT      1.7.5           en           us
# 4                         NaT      1.7.5           en           us
# ...                       ...        ...          ...          ...
# 15158                     NaT       None           en           us
# 15159                     NaT       1.04           en           us
# 15160                     NaT       None           en           us
# 15161                     NaT       None           en           us
# 15162                     NaT       1.01           en           us
#
# [15163 rows x 13 columns]

# %%
a_df = pd.DataFrame(np.array(a_reviews.reviews),columns=['review'])
a_df2 = a_df.join(pd.DataFrame(a_df.pop('review').tolist()))

a_df2.drop(columns={'isEdited'},inplace = True)
a_df2.insert(loc=0, column='source', value='App Store')
a_df2['developer_response_date'] = None
a_df2['thumbs_up'] = None
a_df2['laguage_code'] = 'en'
a_df2['country_code'] = 'us'
a_df2.insert(loc=1, column='review_id', value=[uuid.uuid4() for _ in range(len(a_df2.index))]) 
a_df2.rename(columns= {'review': 'review_description','userName': 'user_name', 'date': 'review_date','title': 'review_title', 'developerResponse': 'developer_response'},inplace = True)
a_df2 = a_df2.where(pd.notnull(a_df2), None)
a_df2
# Out:
#         source                             review_id         review_date  \
# 0    App Store  af327577-7192-4acb-8372-260564af1ded 2023-06-21 12:45:18
# 1    App Store  6a72aee1-9a62-4544-9024-5d8f427cc47e 2022-02-23 20:56:58
# 2    App Store  60ab0c5e-22e3-4fb5-862e-32ac6ec4bca8 2021-11-19 05:46:37
# 3    App Store  b10e73bd-957b-4148-93d2-b8a88f31bc12 2022-10-17 18:52:07
# 4    App Store  162c8d85-8a9b-4d14-bb66-17be84ee0aff 2022-05-30 09:37:48
# ..         ...                                   ...                 ...
# 553  App Store  d1dfa3ad-5cd0-4a03-adb3-2c54868dba42 2021-11-08 00:21:55
# 554  App Store  4ca48f4b-a0c1-472a-abd3-5a78a8ace7f0 2021-12-27 02:43:36
# 555  App Store  cf5d3b2a-0027-4608-9031-b381dabf7321 2021-11-01 16:19:03
# 556  App Store  8f187254-4d81-4c2d-8e88-f5697f1092f6 2021-10-02 19:20:09
# 557  App Store  e98e90c6-6ec9-4ad4-8392-0ccff0c00802 2021-09-04 10:40:39
#
#                                     review_description  rating  \
# 0    This game is absolutely amazing! First of all,...       5
# 1    I absolutely am obsessed with this game!! It’s...       5
# 2    I like the fact that it's not a race against t...       5
# 3    I would rate it 4.5 stars if I could. I thinks...       4
# 4    TL;DR The game is super fun and I love it to p...       3
# ..                                                 ...     ...
# 553         This game is fun and good.Download it now.       5
# 554  This game is fun but after awhile it gets burn...       3
# 555                               Sooooooooooooo goood       5
# 556  I NEVER play games on my phone. This game was ...       5
# 557             Kind of like doing job test for amazon       5
#
#                     user_name  \
# 0             Hayyeeyeecarlos
# 1    Just a small town girl 💗
# 2                  D432578537
# 3                      JG2580
# 4              oreo_chickadee
# ..                        ...
# 553                     siklb
# 554          kuteKrazykoala 3
# 555                 NN fan OG
# 556                Jellypuffs
# 557              Brandalynn83
#
#                                           review_title  \
# 0                                        AWESOME GAME!
# 1    I LOVVVE THIS GAME, just a few problems/sugges...
# 2                                             Relaxing
# 3                         Pretty great but not perfect
# 4                                      Has an ad issue
# ..                                                 ...
# 553                                         Very good.
# 554                                  Koala girl5678934
# 555                                                Omg
# 556                                 Great time waster!
# 557                                          Pass Time
#
#     developer_response_date thumbs_up laguage_code country_code
# 0                      None      None           en           us
# 1                      None      None           en           us
# 2                      None      None           en           us
# 3                      None      None           en           us
# 4                      None      None           en           us
# ..                      ...       ...          ...          ...
# 553                    None      None           en           us
# 554                    None      None           en           us
# 555                    None      None           en           us
# 556                    None      None           en           us
# 557                    None      None           en           us
#
# [558 rows x 11 columns]

# %% [markdown]
# ## Concatenating results between CH Play and AppStore

# %%
result2 = pd.concat([g_df2,a_df2])
result2
# Out:
#           source                             review_id         user_name  \
# 0    Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e    Ernesto Abussi
# 1    Google Play  4558d26c-c223-46f1-a147-6b9e481ca104     Mary Pinkston
# 2    Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329            Viking
# 3    Google Play  e5251950-a650-493f-aa44-bb555906f599      Elsie Ludick
# 4    Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff      Hasan Khalil
# ..           ...                                   ...               ...
# 553    App Store  d1dfa3ad-5cd0-4a03-adb3-2c54868dba42             siklb
# 554    App Store  4ca48f4b-a0c1-472a-abd3-5a78a8ace7f0  kuteKrazykoala 3
# 555    App Store  cf5d3b2a-0027-4608-9031-b381dabf7321         NN fan OG
# 556    App Store  8f187254-4d81-4c2d-8e88-f5697f1092f6        Jellypuffs
# 557    App Store  e98e90c6-6ec9-4ad4-8392-0ccff0c00802      Brandalynn83
#
#            review_title                                 review_description  \
# 0                  None  It's the best adults if r child is under 12 it...
# 1                  None                                            Logical
# 2                  None  Id rate higher if it didnt force the extra bot...
# 3                  None                                     Wonderful game
# 4                  None                                               Nice
# ..                  ...                                                ...
# 553          Very good.         This game is fun and good.Download it now.
# 554   Koala girl5678934  This game is fun but after awhile it gets burn...
# 555                 Omg                               Sooooooooooooo goood
# 556  Great time waster!  I NEVER play games on my phone. This game was ...
# 557           Pass Time             Kind of like doing job test for amazon
#
#      rating thumbs_up         review_date developer_response  \
# 0         5         0 2023-06-23 13:51:00               None
# 1         5         0 2023-06-20 23:00:46               None
# 2         2         0 2023-06-19 06:58:16               None
# 3         5         0 2023-06-19 01:56:45               None
# 4         5         0 2023-06-18 07:50:42               None
# ..      ...       ...                 ...                ...
# 553       5      None 2021-11-08 00:21:55                NaN
# 554       3      None 2021-12-27 02:43:36                NaN
# 555       5      None 2021-11-01 16:19:03                NaN
# 556       5      None 2021-10-02 19:20:09                NaN
# 557       5      None 2021-09-04 10:40:39                NaN
#
#     developer_response_date appVersion laguage_code country_code
# 0                       NaT      1.7.5           en           us
# 1                       NaT      1.5.0           en           us
# 2                       NaT      1.7.5           en           us
# 3                       NaT      1.7.5           en           us
# 4                       NaT      1.7.5           en           us
# ..                      ...        ...          ...          ...
# 553                     NaT        NaN           en           us
# 554                     NaT        NaN           en           us
# 555                     NaT        NaN           en           us
# 556                     NaT        NaN           en           us
# 557                     NaT        NaN           en           us
#
# [15721 rows x 13 columns]

# %% [markdown]
# ## Save result to csv file

# %%
df = pd.DataFrame(result2)  # Chuyển đổi dữ liệu đánh giá thành DataFrame
df.to_csv('result2.csv', index=False)  # Lưu DataFrame vào file CSV

# %%
df_read = pd.read_csv('result2.csv')  # Đọc file CSV
print(df_read.head())  # Hiển thị một số hàng đầu tiên của DataFrame để kiểm tra
# Out:
#         source                             review_id       user_name  \
# 0  Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e  Ernesto Abussi
# 1  Google Play  4558d26c-c223-46f1-a147-6b9e481ca104   Mary Pinkston
# 2  Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329          Viking
# 3  Google Play  e5251950-a650-493f-aa44-bb555906f599    Elsie Ludick
# 4  Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff    Hasan Khalil
#
#   review_title                                 review_description  rating  \
# 0          NaN  It's the best adults if r child is under 12 it...       5
# 1          NaN                                            Logical       5
# 2          NaN  Id rate higher if it didnt force the extra bot...       2
# 3          NaN                                     Wonderful game       5
# 4          NaN                                               Nice       5
#
#    thumbs_up          review_date developer_response developer_response_date  \
# 0        0.0  2023-06-23 13:51:00                NaN                     NaN
# 1        0.0  2023-06-20 23:00:46                NaN                     NaN
# 2        0.0  2023-06-19 06:58:16                NaN                     NaN
# 3        0.0  2023-06-19 01:56:45                NaN                     NaN
# 4        0.0  2023-06-18 07:50:42                NaN                     NaN
#
#   appVersion laguage_code country_code
# 0      1.7.5           en           us
# 1      1.5.0           en           us
# 2      1.7.5           en           us
# 3      1.7.5           en           us
# 4      1.7.5           en           us

# %%
result2
# Out:
#           source                             review_id         user_name  \
# 0    Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e    Ernesto Abussi
# 1    Google Play  4558d26c-c223-46f1-a147-6b9e481ca104     Mary Pinkston
# 2    Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329            Viking
# 3    Google Play  e5251950-a650-493f-aa44-bb555906f599      Elsie Ludick
# 4    Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff      Hasan Khalil
# ..           ...                                   ...               ...
# 553    App Store  d1dfa3ad-5cd0-4a03-adb3-2c54868dba42             siklb
# 554    App Store  4ca48f4b-a0c1-472a-abd3-5a78a8ace7f0  kuteKrazykoala 3
# 555    App Store  cf5d3b2a-0027-4608-9031-b381dabf7321         NN fan OG
# 556    App Store  8f187254-4d81-4c2d-8e88-f5697f1092f6        Jellypuffs
# 557    App Store  e98e90c6-6ec9-4ad4-8392-0ccff0c00802      Brandalynn83
#
#            review_title                                 review_description  \
# 0                  None  It's the best adults if r child is under 12 it...
# 1                  None                                            Logical
# 2                  None  Id rate higher if it didnt force the extra bot...
# 3                  None                                     Wonderful game
# 4                  None                                               Nice
# ..                  ...                                                ...
# 553          Very good.         This game is fun and good.Download it now.
# 554   Koala girl5678934  This game is fun but after awhile it gets burn...
# 555                 Omg                               Sooooooooooooo goood
# 556  Great time waster!  I NEVER play games on my phone. This game was ...
# 557           Pass Time             Kind of like doing job test for amazon
#
#      rating thumbs_up         review_date developer_response  \
# 0         5         0 2023-06-23 13:51:00               None
# 1         5         0 2023-06-20 23:00:46               None
# 2         2         0 2023-06-19 06:58:16               None
# 3         5         0 2023-06-19 01:56:45               None
# 4         5         0 2023-06-18 07:50:42               None
# ..      ...       ...                 ...                ...
# 553       5      None 2021-11-08 00:21:55                NaN
# 554       3      None 2021-12-27 02:43:36                NaN
# 555       5      None 2021-11-01 16:19:03                NaN
# 556       5      None 2021-10-02 19:20:09                NaN
# 557       5      None 2021-09-04 10:40:39                NaN
#
#     developer_response_date appVersion laguage_code country_code
# 0                       NaT      1.7.5           en           us
# 1                       NaT      1.5.0           en           us
# 2                       NaT      1.7.5           en           us
# 3                       NaT      1.7.5           en           us
# 4                       NaT      1.7.5           en           us
# ..                      ...        ...          ...          ...
# 553                     NaT        NaN           en           us
# 554                     NaT        NaN           en           us
# 555                     NaT        NaN           en           us
# 556                     NaT        NaN           en           us
# 557                     NaT        NaN           en           us
#
# [15721 rows x 13 columns]

# %% [markdown]
# # Sentiment Analysis with Python

# %% [markdown]
# Sentiment Analysis: the process of computationally identifying and categorizing opinions expressed in a piece of text, especially in order to determine whether the writer's attitude towards a particular topic, product, etc. is positive, negative, or neutral.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import LatentDirichletAllocation
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %% [markdown]
#  ## Step 1. Read in Data and NLTK Basics

# %%
# Read in Data
df = pd.read_csv("result2.csv")
print(df.shape)
# Out:
# (15721, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15721 entries, 0 to 15720
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   source                   15721 non-null  object
#  1   review_id                15721 non-null  object
#  2   user_name                15721 non-null  object
#  3   review_title             558 non-null    object
#  4   review_description       15721 non-null  object
#  5   rating                   15721 non-null  int64
#  6   thumbs_up                15163 non-null  float64
#  7   review_date              15721 non-null  object
#  8   developer_response       992 non-null    object
#  9   developer_response_date  992 non-null    object
#  10  appVersion               13127 non-null  object
#  11  laguage_code             15721 non-null  object
#  12  country_code             15721 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.6+ MB

# %%
df.head(50)
# Out:
#          source                             review_id  \
# 0   Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e
# 1   Google Play  4558d26c-c223-46f1-a147-6b9e481ca104
# 2   Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329
# 3   Google Play  e5251950-a650-493f-aa44-bb555906f599
# 4   Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff
# 5   Google Play  b0c31bfa-468d-4a34-8c4d-15f56470c87f
# 6   Google Play  f1153b25-09a8-4b7f-9dd7-90b829e074d5
# 7   Google Play  1a271617-3755-4657-aa1f-e73b33fd4676
# 8   Google Play  4910f4b7-8bbb-4385-820c-54be8fcbcf3d
# 9   Google Play  726b018d-ba00-4cda-b419-0cee9c1296fb
# 10  Google Play  665a78c4-b79b-4969-9e81-3ecaa6b923ac
# 11  Google Play  75c6e13b-9845-4efc-a650-43d222b50193
# 12  Google Play  c09a5876-9ec9-4261-893e-14aa0bc2eb85
# 13  Google Play  97a82696-93dc-4110-b356-cfcd7756e132
# 14  Google Play  e1bb4613-4e20-4ef7-9fa1-d00d8341a1c5
# 15  Google Play  7dfa1f22-78c0-4060-ab21-ff85301c8357
# 16  Google Play  a4866c39-cbc3-496f-abb4-6f7a4c132927
# 17  Google Play  2f170ac8-dc46-4522-8c21-fd88c170575c
# 18  Google Play  f4782946-70ab-4aeb-b902-ef01562286ce
# 19  Google Play  e9f88ded-999e-49fd-bb4f-b3dd987dee91
# 20  Google Play  c9988ecb-13f1-49c2-b00e-602869868758
# 21  Google Play  792a754a-32b7-480a-a0da-6675a52a3adf
# 22  Google Play  64b4f10f-53b7-4944-8853-68ab5d48e038
# 23  Google Play  b9a7348c-5a86-4ad6-90af-91b35241018f
# 24  Google Play  008fdde8-f5ce-498a-8eed-4408e64edfef
# 25  Google Play  a1f6d5ac-30c2-4b49-8001-d7b179c7c3bf
# 26  Google Play  9216a6c6-f9d5-45aa-8240-8b7d8dc3049f
# 27  Google Play  c8ac1c99-5f78-4c02-8ce8-f610a4b6d24a
# 28  Google Play  2a11257f-29c0-4dac-a0ce-f8a6aad5c8dd
# 29  Google Play  7af6933f-ad58-4171-bf73-9f30a8d73c1c
# 30  Google Play  670a2b02-241b-4bce-a856-0acfd464c417
# 31  Google Play  2ee13d92-f346-4887-9951-5ac92d61966b
# 32  Google Play  dc5aa41f-0fee-445c-a749-67143ecb76b7
# 33  Google Play  ed0bf311-a537-4318-a7ae-1c2a3fee5da4
# 34  Google Play  c45b8ab3-93cd-4286-b345-776c0c3c05bc
# 35  Google Play  22d69474-c879-4e5a-bd4e-7621ca1361ef
# 36  Google Play  f8966f61-6ff7-42a0-9eee-efe81c7e6f8c
# 37  Google Play  dcb35176-3f03-4905-9959-251e07ddcde7
# 38  Google Play  c3353ea2-b324-409f-85fb-155894dd2a38
# 39  Google Play  8863e282-d204-4f0d-9574-4cebb1ef8531
# 40  Google Play  bbe83803-2dbf-4ba3-8808-b4c07d811497
# 41  Google Play  1b8fe272-ac78-4ff4-a85e-2fa628ea802c
# 42  Google Play  cfc954fc-bb8a-45a8-994c-686fb6fbc114
# 43  Google Play  827e3439-7d09-48e4-b195-91396122ad88
# 44  Google Play  4db4b7b5-485f-4099-8de6-f26a0e3b5b09
# 45  Google Play  c9fe8bee-1788-4c18-bdf5-e784222a4396
# 46  Google Play  4a73d9c2-df11-4179-86c4-76bc91f9fcd0
# 47  Google Play  7ab95ecf-fe52-4df2-a6fd-3392a1178018
# 48  Google Play  b084b3e0-36b0-4c9e-aaec-75e25b8ef14f
# 49  Google Play  f520b4d3-1f53-401a-831b-a58a0e24654d
#
#                     user_name review_title  \
# 0              Ernesto Abussi          NaN
# 1               Mary Pinkston          NaN
# 2                      Viking          NaN
# 3                Elsie Ludick          NaN
# 4                Hasan Khalil          NaN
# 5            Masingita Wonder          NaN
# 6                Hope Chereni          NaN
# 7             Semir Mussa3310          NaN
# 8   Ramsharan Ramsharn gurjar          NaN
# 9           Anil pratap Singh          NaN
# 10           Conrad Rodriguez          NaN
# 11      NorZahirah Mat Zawawi          NaN
# 12                Esther Siko          NaN
# 13                Kaya Cooper          NaN
# 14               Ranya Phipps          NaN
# 15         Iderifama Nicholas          NaN
# 16                 Jae Cloete          NaN
# 17               Tracey James          NaN
# 18          Uzochukwu Obiesie          NaN
# 19                Jagan Mohan          NaN
# 20                   Tuk Poon          NaN
# 21          SD ICE CREAM pure          NaN
# 22                Edwin Omosa          NaN
# 23              Robert Taylor          NaN
# 24               Chiro Andrew          NaN
# 25                   Curtis F          NaN
# 26              Ashrf Alassel          NaN
# 27             Victoria Wills          NaN
# 28   Oluwafayofemi Ayokunnumi          NaN
# 29       pet_rescue_momma13 M          NaN
# 30                     Phoebe          NaN
# 31                  Parker F.          NaN
# 32             Anthony Sutton          NaN
# 33             Linda Odhiambo          NaN
# 34                   Shan Jan          NaN
# 35              Owami Masango          NaN
# 36             Marie Quersher          NaN
# 37       OLUWATISE OLANREWAJU          NaN
# 38            Ntombi Magolide          NaN
# 39                 Steven Tan          NaN
# 40          Nadeesha Dilanthi          NaN
# 41                Brian Mazor          NaN
# 42                samuel john          NaN
# 43                Annie Hyams          NaN
# 44        Muhammad Sani Labbo          NaN
# 45              sheraz zaffar          NaN
# 46                       Lina          NaN
# 47                Selva Kumar          NaN
# 48        Deepakkumar Khaiwar          NaN
# 49  Natividad Familia Pereyra          NaN
#
#                                    review_description  rating  thumbs_up  \
# 0   It's the best adults if r child is under 12 it...       5        0.0
# 1                                             Logical       5        0.0
# 2   Id rate higher if it didnt force the extra bot...       2        0.0
# 3                                      Wonderful game       5        0.0
# 4                                                Nice       5        0.0
# 5                    Lovely game to play during lunch       5        0.0
# 6                                             Amazing       5        0.0
# 7                                      So fantastic 👏       5        0.0
# 8                                                 Xxx       2        0.0
# 9                        Jitne ke bad no mony ricevsd       1        0.0
# 10                                               Nice       5        0.0
# 11                                               Best       5        0.0
# 12  Like this game keeps me busy and away from str...       5        0.0
# 13  When needing to reset the level (I.e. watch an...       1        9.0
# 14                                           Good app       5        0.0
# 15                                          Nice game       5        0.0
# 16  Watch a 30 second ad to only play a level for ...       1        0.0
# 17  I Love it Right now...Not a lot of Ads!...Not ...       5        0.0
# 18                                        interesting       5        0.0
# 19  It is very intresting . I think it will help o...       5        0.0
# 20  Fun and easy once you master it so it becomes ...       2        0.0
# 21                  good game to play when bored nice       2        0.0
# 22                                               Good       1        0.0
# 23  Greeeeedy devs. I've played 6 levels and got 6...       1        0.0
# 24          Good challenging game for kids and adults       4        0.0
# 25  Please please please add multiwindow support. ...       2        0.0
# 26                                          very good       5        0.0
# 27                                              Great       5        0.0
# 28  Awesome game The only annoying thing is you ha...       5        0.0
# 29  Like the game. Wish it was linked to our games...       3        0.0
# 30                Am enjoying. Simple for my kids too       5        0.0
# 31  It was fine till I got somewhere over 1800 lev...       2        1.0
# 32                                          Fun Games       5        0.0
# 33                                            Love it       5        0.0
# 34                                         Good gimme       5        0.0
# 35  This game is a very nice game i play it everyd...       5        0.0
# 36                          Relaxing. Very enjoyable.       4        0.0
# 37                                  Overall best game       5        0.0
# 38                                          Excellent       5        0.0
# 39                                          Nice game       5        0.0
# 40                                           Great 👍🏼       5        0.0
# 41                            Is easy and fun to play       5        0.0
# 42                    Good but how to correct coins 🪙       5        0.0
# 43  Welcome Back And Thank You So Much For The Bea...       5        0.0
# 44                                             Normal       5        0.0
# 45                                             very 👍       5        0.0
# 46       Relaxing so interesting to play....liked it!       5        0.0
# 47                                               GOOD       5        0.0
# 48                                   बहुत ही अच्छा है       5        0.0
# 49  "I don't remember the last time I got hooked o...       5        0.0
#
#             review_date developer_response developer_response_date appVersion  \
# 0   2023-06-23 13:51:00                NaN                     NaN      1.7.5
# 1   2023-06-20 23:00:46                NaN                     NaN      1.5.0
# 2   2023-06-19 06:58:16                NaN                     NaN      1.7.5
# 3   2023-06-19 01:56:45                NaN                     NaN      1.7.5
# 4   2023-06-18 07:50:42                NaN                     NaN      1.7.5
# 5   2023-06-16 19:45:44                NaN                     NaN      1.7.3
# 6   2023-06-15 22:04:38                NaN                     NaN      1.7.5
# 7   2023-06-15 18:01:12                NaN                     NaN      1.7.5
# 8   2023-06-14 14:13:49                NaN                     NaN        NaN
# 9   2023-06-14 07:52:24                NaN                     NaN      1.7.5
# 10  2023-06-12 17:44:08                NaN                     NaN      1.7.5
# 11  2023-06-12 09:43:15                NaN                     NaN      1.7.5
# 12  2023-06-12 00:29:05                NaN                     NaN      1.7.5
# 13  2023-06-10 13:15:16                NaN                     NaN      1.7.5
# 14  2023-06-10 06:38:23                NaN                     NaN      1.7.5
# 15  2023-06-09 01:14:24                NaN                     NaN      1.7.5
# 16  2023-06-07 09:28:48                NaN                     NaN      1.7.3
# 17  2023-06-04 21:19:34                NaN                     NaN      1.7.5
# 18  2023-06-03 23:03:03                NaN                     NaN      1.7.5
# 19  2023-06-01 14:11:52                NaN                     NaN      1.7.2
# 20  2023-06-01 06:14:03                NaN                     NaN        NaN
# 21  2023-05-31 15:49:01                NaN                     NaN      1.7.5
# 22  2023-05-31 03:36:01                NaN                     NaN      1.7.2
# 23  2023-05-30 17:12:39                NaN                     NaN      1.7.5
# 24  2023-05-29 22:06:16                NaN                     NaN      1.7.5
# 25  2023-05-28 02:42:47                NaN                     NaN      1.7.5
# 26  2023-05-27 22:24:12                NaN                     NaN      1.7.5
# 27  2023-05-27 21:28:03                NaN                     NaN      1.7.4
# 28  2023-05-27 19:17:52                NaN                     NaN      1.7.5
# 29  2023-05-26 10:09:48                NaN                     NaN      1.7.5
# 30  2023-05-24 23:55:48                NaN                     NaN      1.7.5
# 31  2023-05-23 04:57:23                NaN                     NaN      1.7.5
# 32  2023-05-22 16:03:43                NaN                     NaN      1.7.5
# 33  2023-05-22 02:07:27                NaN                     NaN      1.7.5
# 34  2023-05-21 20:30:10                NaN                     NaN      1.7.5
# 35  2023-05-21 18:01:43                NaN                     NaN      1.7.5
# 36  2023-05-21 10:50:26                NaN                     NaN      1.7.5
# 37  2023-05-18 22:47:44                NaN                     NaN      1.7.5
# 38  2023-05-18 14:00:29                NaN                     NaN      1.7.5
# 39  2023-05-18 02:13:33                NaN                     NaN      1.7.5
# 40  2023-05-16 22:02:28                NaN                     NaN      1.7.3
# 41  2023-05-16 05:28:01                NaN                     NaN      1.7.2
# 42  2023-05-15 17:35:32                NaN                     NaN      1.7.5
# 43  2023-05-15 01:51:31                NaN                     NaN      1.7.5
# 44  2023-05-13 03:42:58                NaN                     NaN      1.7.5
# 45  2023-05-12 15:33:34                NaN                     NaN      1.7.5
# 46  2023-05-12 02:14:09                NaN                     NaN      1.7.2
# 47  2023-05-12 01:06:15                NaN                     NaN      1.7.3
# 48  2023-05-11 11:30:16                NaN                     NaN      1.7.4
# 49  2023-05-11 05:57:02                NaN                     NaN      1.7.5
#
#    laguage_code country_code
# 0            en           us
# 1            en           us
# 2            en           us
# 3            en           us
# 4            en           us
# 5            en           us
# 6            en           us
# 7            en           us
# 8            en           us
# 9            en           us
# 10           en           us
# 11           en           us
# 12           en           us
# 13           en           us
# 14           en           us
# 15           en           us
# 16           en           us
# 17           en           us
# 18           en           us
# 19           en           us
# 20           en           us
# 21           en           us
# 22           en           us
# 23           en           us
# 24           en           us
# 25           en           us
# 26           en           us
# 27           en           us
# 28           en           us
# 29           en           us
# 30           en           us
# 31           en           us
# 32           en           us
# 33           en           us
# 34           en           us
# 35           en           us
# 36           en           us
# 37           en           us
# 38           en           us
# 39           en           us
# 40           en           us
# 41           en           us
# 42           en           us
# 43           en           us
# 44           en           us
# 45           en           us
# 46           en           us
# 47           en           us
# 48           en           us
# 49           en           us

# %% [markdown]
# ### Drop unused columns

# %%
columns_to_drop = ['thumbs_up', 'developer_response', 'developer_response_date', 'appVersion', 'laguage_code', 'country_code']

df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head(100)
# Out:
#          source                             review_id              user_name  \
# 0   Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e         Ernesto Abussi
# 1   Google Play  4558d26c-c223-46f1-a147-6b9e481ca104          Mary Pinkston
# 2   Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329                 Viking
# 3   Google Play  e5251950-a650-493f-aa44-bb555906f599           Elsie Ludick
# 4   Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff           Hasan Khalil
# ..          ...                                   ...                    ...
# 95  Google Play  1a70d21e-d13e-4c7e-b9cb-1cc5c5094680  Abd El rahman Shahawy
# 96  Google Play  b4118c9d-3810-4e62-b021-97d0bdf2d387            Bunmi Titus
# 97  Google Play  7c064fd7-69fb-4eb2-b639-dc558daec497         Rosemary Lewty
# 98  Google Play  6a31a10b-11a3-4fd4-afad-12d9a3f948e9        Sushanta Mandal
# 99  Google Play  8da5e495-3641-4ae3-83be-a27cdb5893f5           Thar Gyi Lay
#
#    review_title                                 review_description  rating  \
# 0           NaN  It's the best adults if r child is under 12 it...       5
# 1           NaN                                            Logical       5
# 2           NaN  Id rate higher if it didnt force the extra bot...       2
# 3           NaN                                     Wonderful game       5
# 4           NaN                                               Nice       5
# ..          ...                                                ...     ...
# 95          NaN  It is a cheat game ,not sending money as the p...       1
# 96          NaN                                          Beautiful       5
# 97          NaN                       This is so relaxing! Love it       5
# 98          NaN                            Adware. Not recommended       1
# 99          NaN                                              Great       5
#
#             review_date
# 0   2023-06-23 13:51:00
# 1   2023-06-20 23:00:46
# 2   2023-06-19 06:58:16
# 3   2023-06-19 01:56:45
# 4   2023-06-18 07:50:42
# ..                  ...
# 95  2023-04-23 05:53:21
# 96  2023-04-23 03:38:36
# 97  2023-04-23 01:38:08
# 98  2023-04-22 22:45:29
# 99  2023-04-22 09:28:52
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Add ID columns for dataset

# %%
df['ID'] = range(1, len(df) + 1)
df.head(100)
# Out:
#          source                             review_id              user_name  \
# 0   Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e         Ernesto Abussi
# 1   Google Play  4558d26c-c223-46f1-a147-6b9e481ca104          Mary Pinkston
# 2   Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329                 Viking
# 3   Google Play  e5251950-a650-493f-aa44-bb555906f599           Elsie Ludick
# 4   Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff           Hasan Khalil
# ..          ...                                   ...                    ...
# 95  Google Play  1a70d21e-d13e-4c7e-b9cb-1cc5c5094680  Abd El rahman Shahawy
# 96  Google Play  b4118c9d-3810-4e62-b021-97d0bdf2d387            Bunmi Titus
# 97  Google Play  7c064fd7-69fb-4eb2-b639-dc558daec497         Rosemary Lewty
# 98  Google Play  6a31a10b-11a3-4fd4-afad-12d9a3f948e9        Sushanta Mandal
# 99  Google Play  8da5e495-3641-4ae3-83be-a27cdb5893f5           Thar Gyi Lay
#
#    review_title                                 review_description  rating  \
# 0           NaN  It's the best adults if r child is under 12 it...       5
# 1           NaN                                            Logical       5
# 2           NaN  Id rate higher if it didnt force the extra bot...       2
# 3           NaN                                     Wonderful game       5
# 4           NaN                                               Nice       5
# ..          ...                                                ...     ...
# 95          NaN  It is a cheat game ,not sending money as the p...       1
# 96          NaN                                          Beautiful       5
# 97          NaN                       This is so relaxing! Love it       5
# 98          NaN                            Adware. Not recommended       1
# 99          NaN                                              Great       5
#
#             review_date   ID
# 0   2023-06-23 13:51:00    1
# 1   2023-06-20 23:00:46    2
# 2   2023-06-19 06:58:16    3
# 3   2023-06-19 01:56:45    4
# 4   2023-06-18 07:50:42    5
# ..                  ...  ...
# 95  2023-04-23 05:53:21   96
# 96  2023-04-23 03:38:36   97
# 97  2023-04-23 01:38:08   98
# 98  2023-04-22 22:45:29   99
# 99  2023-04-22 09:28:52  100
#
# [100 rows x 8 columns]

# %%
id_column = df.pop('ID')
df.insert(0, 'ID', id_column)
df.head(100)
# Out:
#      ID       source                             review_id  \
# 0     1  Google Play  98fa93e6-9824-4925-be65-703b1bd14b6e
# 1     2  Google Play  4558d26c-c223-46f1-a147-6b9e481ca104
# 2     3  Google Play  fc75e6be-52a2-40cd-889c-5d52d58c5329
# 3     4  Google Play  e5251950-a650-493f-aa44-bb555906f599
# 4     5  Google Play  f8e293e0-c40a-4a33-b941-887a88e540ff
# ..  ...          ...                                   ...
# 95   96  Google Play  1a70d21e-d13e-4c7e-b9cb-1cc5c5094680
# 96   97  Google Play  b4118c9d-3810-4e62-b021-97d0bdf2d387
# 97   98  Google Play  7c064fd7-69fb-4eb2-b639-dc558daec497
# 98   99  Google Play  6a31a10b-11a3-4fd4-afad-12d9a3f948e9
# 99  100  Google Play  8da5e495-3641-4ae3-83be-a27cdb5893f5
#
#                 user_name review_title  \
# 0          Ernesto Abussi          NaN
# 1           Mary Pinkston          NaN
# 2                  Viking          NaN
# 3            Elsie Ludick          NaN
# 4            Hasan Khalil          NaN
# ..                    ...          ...
# 95  Abd El rahman Shahawy          NaN
# 96            Bunmi Titus          NaN
# 97         Rosemary Lewty          NaN
# 98        Sushanta Mandal          NaN
# 99           Thar Gyi Lay          NaN
#
#                                    review_description  rating  \
# 0   It's the best adults if r child is under 12 it...       5
# 1                                             Logical       5
# 2   Id rate higher if it didnt force the extra bot...       2
# 3                                      Wonderful game       5
# 4                                                Nice       5
# ..                                                ...     ...
# 95  It is a cheat game ,not sending money as the p...       1
# 96                                          Beautiful       5
# 97                       This is so relaxing! Love it       5
# 98                            Adware. Not recommended       1
# 99                                              Great       5
#
#             review_date
# 0   2023-06-23 13:51:00
# 1   2023-06-20 23:00:46
# 2   2023-06-19 06:58:16
# 3   2023-06-19 01:56:45
# 4   2023-06-18 07:50:42
# ..                  ...
# 95  2023-04-23 05:53:21
# 96  2023-04-23 03:38:36
# 97  2023-04-23 01:38:08
# 98  2023-04-22 22:45:29
# 99  2023-04-22 09:28:52
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Quick EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15721 entries, 0 to 15720
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  15721 non-null  int64
#  1   source              15721 non-null  object
#  2   review_id           15721 non-null  object
#  3   user_name           15721 non-null  object
#  4   review_title        558 non-null    object
#  5   review_description  15721 non-null  object
#  6   rating              15721 non-null  int64
#  7   review_date         15721 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 982.7+ KB

# %%
sns.color_palette("RdBu_r")
ax = sns.countplot(x=df["rating"])
ax.set(xlabel='Rating', ylabel='Number of Reviews',
       title='Number of reviews per Rating group')

for p in ax.patches:
    txt = str(((p.get_height()/15721 )*100).round(2)) + '%'
    txt_x = p.get_x() + 0.1
    txt_y = p.get_height() +5
    ax.text(txt_x,txt_y,txt)

plt.show()

# %% [markdown]
# ### Data transformation

# %%
df['review_description_lower'] = df['review_description'].astype(str).str.lower()
df.head(5)
# Out:
#   review_title                                 review_description  \
# 0          NaN  It's the best adults if r child is under 12 it...
# 1          NaN                                            Logical
# 2          NaN  Id rate higher if it didnt force the extra bot...
# 3          NaN                                     Wonderful game
# 4          NaN                                               Nice
#
#                             review_description_lower  rating  \
# 0  it's the best adults if r child is under 12 it...       5
# 1                                            logical       5
# 2  id rate higher if it didnt force the extra bot...       2
# 3                                     wonderful game       5
# 4                                               nice       5
#
#    0_GameDifficulty  1_GamePlay  2_GamingExperience      review_topic  \
# 0          0.450489    0.128723            0.420787    GameDifficulty
# 1          0.166845    0.179741            0.653414  GamingExperience
# 2          0.215953    0.753701            0.030346          GamePlay
# 3          0.542461    0.114942            0.342597    GameDifficulty
# 4          0.166667    0.166667            0.666665  GamingExperience
#
#                            lemmatized_processed_text
# 0  ['s, best, adult, r, child, 12, actually, take...
# 1                                          [Logical]
# 2  [Id, rate, higher, didnt, force, extra, bottle...
# 3                                  [Wonderful, game]
# 4                                             [Nice]

# %% [markdown]
# ### Extracting relevant features for topic modelling

# %%
tm_df = df[["review_title", "review_description", "review_description_lower", "rating"]]
tm_df.head(5)
# Out:
#   review_title                                 review_description  \
# 0          NaN  It's the best adults if r child is under 12 it...
# 1          NaN                                            Logical
# 2          NaN  Id rate higher if it didnt force the extra bot...
# 3          NaN                                     Wonderful game
# 4          NaN                                               Nice
#
#                             review_description_lower  rating
# 0  it's the best adults if r child is under 12 it...       5
# 1                                            logical       5
# 2  id rate higher if it didnt force the extra bot...       2
# 3                                     wonderful game       5
# 4                                               nice       5

# %% [markdown]
# ## Step 2. Topic modeling using LDA

# %% [markdown]
# ## converting reviews to document term matrix

# %%
# discards words that occur in more than 97% of documents, and include words that occur at least in 2 documents
cv = CountVectorizer(max_df=0.97, min_df=2, stop_words='english')
doc_term_matrix = cv.fit_transform(tm_df['review_description_lower'])
doc_term_matrix
# Out:
# <15721x2631 sparse matrix of type '<class 'numpy.int64'>'
# 	with 51517 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### hyperparameter tuning using gridsearch

# %%
lda=LatentDirichletAllocation(random_state=101, n_jobs=-1)
param_grid = { 
    'n_components': [3, 4, 5, 10, 15],
    'max_iter': [5, 10, 15, 20, 25],
    'learning_decay': [.5, .7, .9]
}

# %%
LDA=LatentDirichletAllocation(random_state=101, n_jobs=-1, learning_decay = 0.5, max_iter = 25, n_components = 3)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(learning_decay=0.5, max_iter=25, n_components=3,
#                           n_jobs=-1, random_state=101)

# %%
for index,topic in enumerate(LDA.components_):
    print(f'topic #{index} : ')
    print([cv.get_feature_names_out()[i] for i in topic.argsort()[-30:]])
# Out:
# topic #0 :
# ['download', 'water', 'free', 'got', 'enjoy', 'colors', 'makes', 'hard', 'make', 'way', 'bad', 'think', 'pass', 'playing', 'adds', 'challenging', 'levels', 'games', 'don', 'level', 'really', 'just', 'play', 'easy', 'super', 'ads', 'app', 'time', 'like', 'game']
# topic #1 :
# ['annoying', 'option', 'button', 'bottle', 'need', 'simple', 'hai', 'bored', 'challenge', 'tube', 'boring', 'puzzle', 'new', 'add', 'extra', 'entertaining', 'keeps', 'playing', 'just', 'watch', 'play', 'ok', 'addictive', 'awesome', 'ad', 'level', 'game', 'ads', 'love', 'fun']
# topic #2 :
# ['puzzle', 'work', 'thanks', 'relax', 'stress', 'enjoy', 'kids', 'far', 'satisfying', 'beautiful', 'thinking', 'superb', 'enjoying', 'thank', 'fantastic', 'helps', 'play', 'excellent', 'really', 'cool', 'amazing', 'interesting', 'brain', 'best', 'mind', 'relaxing', 'great', 'nice', 'good', 'game']

# %%
tm_df = tm_df.reset_index(drop=True)

# %%
topic = LDA.transform(doc_term_matrix)
df_topic = pd.DataFrame(topic, columns=[
'0_GameDifficulty',
'1_GamePlay' ,
'2_GamingExperience'
])
df = pd.merge(tm_df, df_topic,  how='inner', left_index=True, right_index=True )

# %%
def return_topic(row):
    if row["1_GamePlay"] > row["0_GameDifficulty"] and row["1_GamePlay"] > row["2_GamingExperience"]:
        return "GamePlay"
    if row["0_GameDifficulty"] > row["1_GamePlay"] and row["0_GameDifficulty"] > row["2_GamingExperience"]:
        return "GameDifficulty"
    if row["2_GamingExperience"] > row["0_GameDifficulty"] and row["2_GamingExperience"] > row["1_GamePlay"]:
        return "GamingExperience"

# %%
df["review_topic"] = df.apply(lambda x: return_topic(x), axis=1)

# %%
df.head(5)
# Out:
#   review_title                                 review_description  \
# 0          NaN  It's the best adults if r child is under 12 it...
# 1          NaN                                            Logical
# 2          NaN  Id rate higher if it didnt force the extra bot...
# 3          NaN                                     Wonderful game
# 4          NaN                                               Nice
#
#                             review_description_lower  rating  \
# 0  it's the best adults if r child is under 12 it...       5
# 1                                            logical       5
# 2  id rate higher if it didnt force the extra bot...       2
# 3                                     wonderful game       5
# 4                                               nice       5
#
#    0_GameDifficulty  1_GamePlay  2_GamingExperience      review_topic
# 0          0.450489    0.128723            0.420787    GameDifficulty
# 1          0.166845    0.179741            0.653414  GamingExperience
# 2          0.215953    0.753701            0.030346          GamePlay
# 3          0.542461    0.114942            0.342597    GameDifficulty
# 4          0.166667    0.166667            0.666665  GamingExperience

# %%
ax = sns.countplot(data=df, y="review_topic", hue="rating")
ax.set(xlabel='Number of Reviews', ylabel='Issue Topic',
       title='Distribution of Ratings per Topic')

plt.show()

# %% [markdown]
# It is easy to see that the number of 5-star reviews is overwhelming compared to the rest of the reviews. People seems to be quite satisfied with all features.
# We can see that features for gaming experience created the highest number of reviewers, follow by game difficulty and lastly gameplay for facilities.

# %% [markdown]
# ## Step 3. Wordcloud of positive and negative reviews

# %%
# !pip install -q contractions

# %%
import nltk
import re
from nltk.corpus import stopwords
import contractions
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud

# %%
df.head(5)
# Out:
#   review_title                                 review_description  \
# 0          NaN  It's the best adults if r child is under 12 it...
# 1          NaN                                            Logical
# 2          NaN  Id rate higher if it didnt force the extra bot...
# 3          NaN                                     Wonderful game
# 4          NaN                                               Nice
#
#                             review_description_lower  rating  \
# 0  <bound method Series.apply of 0        it's th...       5
# 1  <bound method Series.apply of 0        it's th...       5
# 2  <bound method Series.apply of 0        it's th...       2
# 3  <bound method Series.apply of 0        it's th...       5
# 4  <bound method Series.apply of 0        it's th...       5
#
#    0_GameDifficulty  1_GamePlay  2_GamingExperience      review_topic
# 0          0.450489    0.128723            0.420787    GameDifficulty
# 1          0.166845    0.179741            0.653414  GamingExperience
# 2          0.215953    0.753701            0.030346          GamePlay
# 3          0.542461    0.114942            0.342597    GameDifficulty
# 4          0.166667    0.166667            0.666665  GamingExperience

# %% [markdown]
# ### Data cleaning

# %%
def clean_text(text):
    text = text.lower()
    # remove \n \t and non-alphanumeric
    text = re.sub("(\\t|\\n)", " ", text)
    text = re.sub("[^a-zA-Z']", " ", text)
    text = re.sub("(?:_|[^a-z0-9_:])[;:=]+[\)\(\-\[\]\/|DPO]", "", text)
    text = re.sub("[0-9]+", "", text)
    text = text.strip()
    # expanding the contractions
    text = ' '.join([contractions.fix(x) for x in text.split(" ")])
    return text.strip()

df["review_description_lower"] = df["review_description_lower"].apply
(lambda x: clean_text(x))
# Out:
# <function __main__.<lambda>(x)>

# %%
#data pre-processing - LEMMATIZATION
def lemma_preprocess_text(text_list):
    processed_text = []
     
    #Tokenize words
    tokens = [word_tokenize(text) for text in text_list]
    
    #Remove stop words
    stop_list = stopwords.words('english')
    stop_list.append("filler")
    text_stop = [[word for word in doc if word.lower() not in stop_list] for doc in tokens]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    text_lemma = [[lemmatizer.lemmatize(word) for word in doc] for doc in text_stop]
    
    return text_lemma

# %%
# Put each row of the 'review_description' column into a list on its own
text_list = df['review_description_lower'].tolist()

# Preprocess the text_list
lemma_processed_text = lemma_preprocess_text(text_list)

# Add the processed_text list as a new column in the dataframe
df['lemmatized_processed_text'] = lemma_processed_text

# Preview the processed data
df.head(5)
# Out:
#   review_title                                 review_description  \
# 0          NaN  It's the best adults if r child is under 12 it...
# 1          NaN                                            Logical
# 2          NaN  Id rate higher if it didnt force the extra bot...
# 3          NaN                                     Wonderful game
# 4          NaN                                               Nice
#
#                             review_description_lower  rating  \
# 0  it's the best adults if r child is under 12 it...       5
# 1                                            logical       5
# 2  id rate higher if it didnt force the extra bot...       2
# 3                                     wonderful game       5
# 4                                               nice       5
#
#    0_GameDifficulty  1_GamePlay  2_GamingExperience      review_topic  \
# 0          0.450489    0.128723            0.420787    GameDifficulty
# 1          0.166845    0.179741            0.653414  GamingExperience
# 2          0.215953    0.753701            0.030346          GamePlay
# 3          0.542461    0.114942            0.342597    GameDifficulty
# 4          0.166667    0.166667            0.666665  GamingExperience
#
#                            lemmatized_processed_text
# 0  ['s, best, adult, r, child, 12, actually, take...
# 1                                          [logical]
# 2  [id, rate, higher, didnt, force, extra, bottle...
# 3                                  [wonderful, game]
# 4                                             [nice]

# %%
# reviews with rating >= 4
four_and_five = df[['rating'] >= 4]

# reviews with rating < 4
less_than_4 = df[df['rating'] < 4]

# %% [markdown]
# ### Normal wordcloud

# %%
# 4&5 RATINGS  - word cloud

# extract the processed text column as a list of lists

four_and_five_text = four_and_five['lemmatized_processed_text'].tolist()

# join each inner list into a single string
four_and_five_rev_text = [" ".join(x) for x in four_and_five_text]

# join the list of strings into a single string
four_and_five_rev_text = " ".join(four_and_five_rev_text)

# tokenize the words
four_and_five_rev_tokens = word_tokenize(four_and_five_rev_text)

# create a word cloud
review_wordcloud = WordCloud(width = 3000, height = 2000, background_color="white").generate(" ".join(four_and_five_rev_tokens))

# plot the word cloud
plt.figure(figsize=(8,6))
plt.imshow(review_wordcloud, interpolation='bilinear')
plt.title("Word Cloud of Positive Reviews")
plt.axis("off")
plt.show()

# %%
# LESS THAN 4 RATINGS  - word cloud

# extract the processed text column as a list of lists

less_than_4_text = less_than_4['lemmatized_processed_text'].tolist()

# join each inner list into a single string
less_than_4_rev_text = [" ".join(x) for x in less_than_4_text]

# join the list of strings into a single string
less_than_4_rev_text = " ".join(less_than_4_rev_text)

# tokenize the words
less_than_4_rev_tokens = word_tokenize(less_than_4_rev_text)

# create a word cloud
# wordcloud = WordCloud().generate(" ".join(tokens))
review_wordcloud = WordCloud(width = 3000, height = 2000, background_color="black").generate(" ".join(less_than_4_rev_tokens))

# plot the word cloud
plt.figure(figsize=(8,6))
plt.imshow(review_wordcloud, interpolation='bilinear')
plt.title("Word Cloud of Negative Reviews")
plt.axis("off")
plt.show()

# %% [markdown]
# Most of the words are indeed related to the game difficulty and users' experience: fun, good, game, level, ads, etc. Some negative words are more related to the users experience with the game: easy, ads, level, boring, best, etc.

# %% [markdown]
# ## Step 4. VADER Sentiment Scoring

# %% [markdown]
# We will use NLTK's SentimentIntesityAnalyzer to get the neg/neu/pos scores of the text.
# This uses a "bag of words" approach:
#     1. Stop words are removed
#     2. Each word is scored and combined to a total score

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %% [markdown]
# ### Run the polarity score on the entire dataset

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    review = row['review_description']
    myid = row['ID']
    res[myid] = sia.polarity_scores(review)
# Out:
#   0%|          | 0/15721 [00:00<?, ?it/s]

# %% [markdown]
# ### Add the result to the dataset

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'ID'})
vaders = vaders.merge(df, how='left')

# %%
vaders.head(10)
# Out:
#    ID    neg    neu    pos  compound       source  \
# 0   1  0.000  0.717  0.283    0.9118  Google Play
# 1   2  0.000  1.000  0.000    0.0000  Google Play
# 2   3  0.000  1.000  0.000    0.0000  Google Play
# 3   4  0.000  0.213  0.787    0.5719  Google Play
# 4   5  0.000  0.000  1.000    0.4215  Google Play
# 5   6  0.000  0.392  0.608    0.7351  Google Play
# 6   7  0.000  0.000  1.000    0.5859  Google Play
# 7   8  0.000  0.204  0.796    0.5984  Google Play
# 8   9  0.000  1.000  0.000    0.0000  Google Play
# 9  10  0.588  0.412  0.000   -0.6908  Google Play
#
#                               review_id                  user_name  \
# 0  98fa93e6-9824-4925-be65-703b1bd14b6e             Ernesto Abussi
# 1  4558d26c-c223-46f1-a147-6b9e481ca104              Mary Pinkston
# 2  fc75e6be-52a2-40cd-889c-5d52d58c5329                     Viking
# 3  e5251950-a650-493f-aa44-bb555906f599               Elsie Ludick
# 4  f8e293e0-c40a-4a33-b941-887a88e540ff               Hasan Khalil
# 5  b0c31bfa-468d-4a34-8c4d-15f56470c87f           Masingita Wonder
# 6  f1153b25-09a8-4b7f-9dd7-90b829e074d5               Hope Chereni
# 7  1a271617-3755-4657-aa1f-e73b33fd4676            Semir Mussa3310
# 8  4910f4b7-8bbb-4385-820c-54be8fcbcf3d  Ramsharan Ramsharn gurjar
# 9  726b018d-ba00-4cda-b419-0cee9c1296fb          Anil pratap Singh
#
#   review_title                                 review_description  rating  \
# 0          NaN  It's the best adults if r child is under 12 it...       5
# 1          NaN                                            Logical       5
# 2          NaN  Id rate higher if it didnt force the extra bot...       2
# 3          NaN                                     Wonderful game       5
# 4          NaN                                               Nice       5
# 5          NaN                   Lovely game to play during lunch       5
# 6          NaN                                            Amazing       5
# 7          NaN                                     So fantastic 👏       5
# 8          NaN                                                Xxx       2
# 9          NaN                       Jitne ke bad no mony ricevsd       1
#
#            review_date
# 0  2023-06-23 13:51:00
# 1  2023-06-20 23:00:46
# 2  2023-06-19 06:58:16
# 3  2023-06-19 01:56:45
# 4  2023-06-18 07:50:42
# 5  2023-06-16 19:45:44
# 6  2023-06-15 22:04:38
# 7  2023-06-15 18:01:12
# 8  2023-06-14 14:13:49
# 9  2023-06-14 07:52:24

# %%
vaders.describe()
# Out:
#                  ID           neg           neu           pos      compound  \
# count  15721.000000  15721.000000  15721.000000  15721.000000  15721.000000
# mean    7861.000000      0.037220      0.477332      0.477370      0.354864
# std     4538.406126      0.122919      0.362765      0.378846      0.354476
# min        1.000000      0.000000      0.000000      0.000000     -0.985300
# 25%     3931.000000      0.000000      0.196000      0.000000      0.000000
# 50%     7861.000000      0.000000      0.432000      0.499000      0.440400
# 75%    11791.000000      0.000000      0.804000      0.794000      0.624900
# max    15721.000000      1.000000      1.000000      1.000000      0.998000
#
#              rating
# count  15721.000000
# mean       4.228230
# std        1.342947
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# ### Plot VADER results

# %%
vaders.boxplot(column=['compound'], by='rating').set(xlabel='Rating')
plt.title('') 
plt.ylabel('Compound Sentiment Scores')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='rating', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='rating', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='rating', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# It confirms what I hope to see and shows that vader is valuable in having this connection between the score of the text and sentiment rating. It relates to the actual rating review of the users. We can see that positivity is higher as the rating is higher in terms of stars and vice versa.
